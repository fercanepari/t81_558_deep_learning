# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import pandas as pd

df = pd.read_csv('iris.csv')

df.describe()
df.shape
df.head(3)
# Out:
#     PL   PW   SL   SW       Specie
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa

# %%
import numpy as np

# %%
df = pd.read_csv('iris.csv', usecols=[0,1,2,3])
data = np.float32(df)
data_tensor = tf.convert_to_tensor(data, dtype=tf.float32)
res = tf.add(data_tensor, 3)

sess = tf.Session()
sess.run(res)
# Out:
# array([[ 8.1,  6.5,  4.4,  3.2],
#        [ 7.9,  6. ,  4.4,  3.2],
#        [ 7.7,  6.2,  4.3,  3.2],
#        [ 7.6,  6.1,  4.5,  3.2],
#        [ 8. ,  6.6,  4.4,  3.2],
#        [ 8.4,  6.9,  4.7,  3.4],
#        [ 7.6,  6.4,  4.4,  3.3],
#        [ 8. ,  6.4,  4.5,  3.2],
#        [ 7.4,  5.9,  4.4,  3.2],
#        [ 7.9,  6.1,  4.5,  3.1],
#        [ 8.4,  6.7,  4.5,  3.2],
#        [ 7.8,  6.4,  4.6,  3.2],
#        [ 7.8,  6. ,  4.4,  3.1],
#        [ 7.3,  6. ,  4.1,  3.1],
#        [ 8.8,  7. ,  4.2,  3.2],
#        [ 8.7,  7.4,  4.5,  3.4],
#        [ 8.4,  6.9,  4.3,  3.4],
#        [ 8.1,  6.5,  4.4,  3.3],
#        [ 8.7,  6.8,  4.7,  3.3],
#        [ 8.1,  6.8,  4.5,  3.3],
#        [ 8.4,  6.4,  4.7,  3.2],
#        [ 8.1,  6.7,  4.5,  3.4],
#        [ 7.6,  6.6,  4. ,  3.2],
#        [ 8.1,  6.3,  4.7,  3.5],
#        [ 7.8,  6.4,  4.9,  3.2],
#        [ 8. ,  6. ,  4.6,  3.2],
#        [ 8. ,  6.4,  4.6,  3.4],
#        [ 8.2,  6.5,  4.5,  3.2],
# ...
