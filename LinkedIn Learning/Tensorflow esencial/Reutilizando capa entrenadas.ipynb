# %% [markdown]
# En generar no debemos entrenar DNN grandes
#
# Aprovechar la transferencia de aprendizaje
#
#
#
# <img src="mlst_1104.png" width="400">
#
# Ejemplo:
#
# El modelo de MobileNet V2 desarrollado por Google y preentrenado con el dataset ImageNet
#
# De esta forma cargamos el modelo entrenado, tf.keras.applicartions.MobileNetV2 que ha sido entrenado en ImageNet
#
#
# ```
#
# # Creando modelo del modelo preentrenado model MobileNet V2
# base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
#                                                include_top=False,
#                                                weights='imagenet')
#
# ```

# %%
IMG_SHAPE = (160, 160, 3)

base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_160"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 161, 161, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 80, 80, 32)   864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 80, 80, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 80, 80, 32)   0           bn_Conv1[0][0]
# ...
